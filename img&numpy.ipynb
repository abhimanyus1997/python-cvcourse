# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# >Helps to display matplot inline in older matplotlin

# %%
from PIL import Image

# %%
pic = Image.open('puppy.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=680x453 at 0x1A43F9276A0>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
picarr = np.asarray(pic)

# %%
type(picarr)
# Out:
# numpy.ndarray

# %%
picarr.shape
# Out:
# (453, 680, 3)

# %%
plt.imshow(picarr)

# %%
picR = picarr.copy()
pic_red = picR[:,:,0]

#pic_green = pic_green[:,:,1]
#pic_blue = pic_blue[:,:,2]

# %% [markdown]
# </br>
# <h3>Red Channel</h3>

# %%
# Red
#plt.imshow(pic_red)

# %%
plt.imshow(pic_red,cmap='gray')

# %% [markdown]
# >Red Channel in Gray Color Map

# %%
picR[:,:,1] = 0
picR[:,:,2] = 0

# %% [markdown]
# >Setting all other channels values to 0

# %%
plt.imshow(picR)
